# %% [markdown]
# #### Functions Examples

# %% [markdown]
# #### Example 1. Temperature conversion

# %%
def convert_temperature(temp,unit):
    """This function converts temperatue between celcius and fahrenheit"""

    if unit == 'C':
        return temp * 9/5 + 32  ## celcius to Fahreheit 
    
    elif unit == "F":
        return (temp-32) * 5/9  ## Fahreheit to celcius 
    else:
        return None
    
print(convert_temperature(23,"C"))  
print(convert_temperature(74,"F"))
# Out:
# 73.4
# 23.333333333333332

# %% [markdown]
# #### Example 2. Password Strength Checker

# %%
def is_strong_password(password):
    """This function checks if the password is strong or not """

    if len(password) <8:
        return False
    if not any(char.isdigit() for char in password):
        return False
    if not any(char.islower() for char in password):
        return False
    if not any(char.isupper() for char in password):
        return False
    if not any(char in "!@#$%^&*()_+" for char in password):
        return False
    return True

### calling the function 
print(is_strong_password("weakPass"))
print(is_strong_password("Adi2005@"))
# Out:
# False
# True

# %% [markdown]
# #### Example 3. Calculate  the total cost of items in shopping cart

# %%
def calculate_total_cost(cart):
    total_cost = 0
    for item in cart:
        total_cost += item['price'] * item['quantity']

    return total_cost    


## Example cart data

cart=[
    {'name':'Apple','price':0.5,'quantity':4},
    {'name':'Banana','price':0.3,'quantity':6},
    {'name':'Orange','price':0.7,'quantity':3}


]

## calling the function
total_cost =calculate_total_cost(cart)
print(total_cost)
# Out:
# 5.8999999999999995

# %% [markdown]
# #### Example 4. Checks if a string is palindrome

# %%
def is_palindrome(s):
    s = s.lower().replace(" ","")
    return s == s[::-1]

print(is_palindrome("A man a plan a canal panama"))
# Out:
# True

# %% [markdown]
# #### Example 5. Factorial of a number using recursion

# %%
def factorial(n):
    if n==0:
        return 1
    
    else:
        return n * factorial(n-1)
    
print(factorial(6))
# Out:
# 720

# %% [markdown]
# #### Example 6. A function to read and count the frequency of each word

# %%
def count_word_frequency(file_path):
    word_count={}
    with open(file_path,'r') as file:
        for line in file:
            words=line.split()
            for word in words:
                word=word.lower().strip('.,!?;:"\'')
                word_count[word]=word_count.get(word,0)+1  ## dictionary method 
    
    return word_count

filepath='sample.txt'
word_frequency=count_word_frequency(filepath)
print(word_frequency)
# Out:
# {'Hello': 1, 'World': 1, 'How': 1, 'are': 1, 'you': 1, 'My': 1, 'name': 1, 'is': 1, 'Krish': 1, 'KRish': 1}
